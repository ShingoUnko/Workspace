# %% [markdown]
# # StrixのタスキングCSVを出力します。
#
# gs://appsci-notebook-env/test_data/Stri-X_Taskng/Input<Br>
# のフォルダの中に<Br><Br>
# ・Aoi_List.csv<Br>
# ・Opp_List.csv<Br><Br>
# のファイルを格納して下さい。

# %%
# %run ObsTargetFilter.py
# Out:
# [メッセージ]処理開始
# df_opl_in                      aoiName  Satname observation_jst_time  offnadir_angl  \
# 0    [AT] Ishikawa_Nanao_SM2  StriX-1       2024/6/17 0:04      32.911302
# 1    [AT] Ishikawa_Nanao_SM2  StriX-1       2024/6/17 0:05      21.823617
# 2    [AT] Ishikawa_Nanao_SM2  StriX-1       2024/6/17 0:06      26.923083
# 3    [AT] Ishikawa_Nanao_SM2  StriX-1       2024/6/17 0:06      24.347534
# 4    [AT] Ishikawa_Nanao_SM2  StriX-1       2024/6/17 0:06      27.067899
# ..                       ...      ...                  ...            ...
# 290  [AT] Ishikawa_Nanao_SM2  StriX-3      2024/6/23 17:59      40.263135
# 291  [AT] Ishikawa_Nanao_SM2  StriX-3      2024/6/23 17:59      39.171616
# 292  [AT] Ishikawa_Nanao_SM2  StriX-3      2024/6/23 17:59      40.697772
# 293  [AT] Ishikawa_Nanao_SM2  StriX-3      2024/6/23 17:59      38.089885
# 294  [AT] Ishikawa_Nanao_SM2  StriX-3      2024/6/23 17:59      42.624863
#
#     looking_direction flight_direction
# ...
